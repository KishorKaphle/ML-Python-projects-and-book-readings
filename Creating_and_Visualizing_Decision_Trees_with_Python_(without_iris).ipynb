# %% [markdown]
# <a href="https://colab.research.google.com/github/KishorKaphle/ML-Python-projects-and-book-readings/blob/main/Creating_and_Visualizing_Decision_Trees_with_Python_(without_iris).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating and Visualizing Decision Trees with Python
#
# Adapted from https://medium.com/@rnbrown/creating-and-visualizing-decision-trees-with-python-f8e8fa394176, using example from https://stackoverflow.com/a/22832498/1840471.

# %% [markdown]
# ## Imports
#
# `pydotplus` isn't in Colab by default.

# %%
# !apt-get install python-pydot
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-pydot is already the newest version (1.2.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
# !pip install pydotplus

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus

# %% [markdown]
# ## Build tree

# %%
np.random.seed(0)
X = np.random.randn(10, 4)
y = np.array(["foo", "bar", "baz"])[np.random.randint(0, 3, 10)]
clf = DecisionTreeClassifier(random_state=42).fit(X, y)

# %% [markdown]
# ## Visualize

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
